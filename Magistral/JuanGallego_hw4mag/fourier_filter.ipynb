# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft,fftfreq,ifft
from scipy.io import wavfile

# %%
fs,data = wavfile.read('sheep.wav')

# %%
data_norm=data*1./abs(data).max()

# %%
t=np.arange(0,len(data)*1./fs,1/(fs*1.))
n_t=len(data)
dt=1/(fs*1.)
t
# Out:
# array([  0.00000000e+00,   2.26757370e-05,   4.53514739e-05, ...,
#          1.06210884e+00,   1.06213152e+00,   1.06215420e+00])

# %%
freq=fftfreq(n_t,1/(fs*1.))
c=fft(data_norm[:,0])
freq_cut = 500

# %%
c[abs(freq) > freq_cut] = 0
clean_f = ifft(c) 
wavfile.write('sheep_f.wav',fs,np.real(clean_f))

# %%
x=[]
for i in range (len(data)-1):
    x.append(data[i])

# %%
xx=np.linspace(0,len(x)-1,len(x))
len(xx)
plt.plot(xx,x)
plt.show()

# %%
fs,data1 = wavfile.read('sheep_f.wav')

# %%
x=[]
for i in range (len(data1)-1):
    x.append(data1[i])

# %%
xx=np.linspace(0,len(x)-1,len(x))
len(xx)
plt.plot(xx,x)
plt.show()
