# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft,fftfreq,ifft
from scipy.signal import convolve
import pandas as pd
from scipy.interpolate import lagrange, interp1d 
from scipy.optimize import leastsq
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tbl = pd.read_table('kplr000757450_q1_q16_tce_01_dvt_lc.tbl',delim_whitespace=True)
tbl.values[:,0]
# Out:
# array([  131.5127147,   131.5331494,   131.553584 , ...,  1557.9179758,
#         1557.9384103,  1557.9588447])

# %%
print tbl
# Out:
#                  1      2         3         4  5         6         7
# 0       131.512715   1105  0.000001  0.000462  0 -0.000018  0.000462
# 1       131.533149   1106 -0.000294  0.000462  0 -0.000312  0.000462
# 2       131.553584   1107  0.000273  0.000462  0  0.000254  0.000462
# 3       131.574018   1108 -0.000331  0.000462  0 -0.000350  0.000462
# 4       131.594453   1109 -0.000569  0.000462  0 -0.000588  0.000462
# 5       131.614888   1110  0.000204  0.000462  0  0.000185  0.000462
# 6       131.635322   1111  0.000253  0.000462  0  0.000234  0.000462
# 7       131.655757   1112 -0.000120  0.000463  0 -0.000139  0.000463
# 8       131.676192   1113  0.001139  0.000463  0  0.001120  0.000463
# 9       131.696626   1114 -0.000982  0.000462  0 -0.001001  0.000462
# 10      131.717061   1115  0.000078  0.000462  0  0.000059  0.000462
# 11      131.737495   1116 -0.000638  0.000462  0 -0.000656  0.000462
# 12      131.757930   1117 -0.000068  0.000462  0 -0.000087  0.000462
# 13      131.778365   1118  0.000259  0.000462  0  0.000240  0.000462
# 14      131.798799   1119  0.000419  0.000462  0  0.000400  0.000462
# 15      131.819234   1120  0.000929  0.000462  0  0.000910  0.000462
# 16      131.839669   1121 -0.000037  0.000462  0 -0.000055  0.000462
# 17      131.860103   1122 -0.000495  0.000462  0 -0.000513  0.000462
# 18      131.880538   1123  0.000277  0.000462  0  0.000258  0.000462
# 19      131.900972   1124 -0.000675  0.000462  0 -0.000694  0.000462
# 20      131.921407   1125 -0.000439  0.000462  0 -0.000458  0.000462
# 21      131.941842   1126 -0.000411  0.000462  0 -0.000429  0.000462
# 22      131.962276   1127  0.000938  0.000462  0  0.000919  0.000462
# 23      131.982711   1128  0.000163  0.000462  0  0.000145  0.000462
# 24      132.003145   1129 -0.000614  0.000462  0 -0.000633  0.000462
# 25      132.023580   1130 -0.000172  0.000462  0 -0.000191  0.000462
# 26      132.044015   1131 -0.000733  0.000462  0 -0.000752  0.000462
# 27      132.064449   1132  0.001713  0.000462  0  0.001694  0.000462
# 28      132.084884   1133  0.000065  0.000462  0  0.000046  0.000462
# 29      132.105318   1134 -0.000743  0.000462  0 -0.000761  0.000462
# ...            ...    ...       ...       ... ..       ...       ...
# 69780  1557.366246  70885 -0.000424  0.000559  0 -0.000443  0.000559
# 69781  1557.386681  70886  0.000618  0.000559  0  0.000599  0.000559
# 69782  1557.407115  70887 -0.000901  0.000559  0 -0.000920  0.000559
# 69783  1557.427549  70888  0.000364  0.000559  0  0.000345  0.000559
# 69784  1557.447984  70889 -0.000168  0.000559  0 -0.000186  0.000559
# 69785  1557.468418  70890 -0.000457  0.000559  0 -0.000476  0.000559
# 69786  1557.488853  70891  0.000345  0.000559  0  0.000326  0.000559
# 69787  1557.509287  70892  0.002169  0.000559  0  0.002150  0.000559
# 69788  1557.529722  70893  0.000374  0.000559  0  0.000355  0.000559
# 69789  1557.550156  70894  0.000187  0.000559  0  0.000168  0.000559
# 69790  1557.570590  70895  0.000248  0.000559  0  0.000230  0.000559
# 69791  1557.591025  70896 -0.000010  0.000559  0 -0.000029  0.000559
# 69792  1557.611459  70897 -0.001486  0.000559  0 -0.001505  0.000559
# 69793  1557.631894  70898 -0.000909  0.000559  0 -0.000928  0.000559
# 69794  1557.652328  70899 -0.001010  0.000559  0 -0.001029  0.000559
# 69795  1557.672763  70900 -0.001501  0.000559  0 -0.001520  0.000559
# 69796  1557.693197  70901 -0.001871  0.000559  0 -0.001890  0.000559
# 69797  1557.713632  70902 -0.001977  0.000559  0 -0.001996  0.000559
# 69798  1557.734066  70903 -0.001421  0.000559  0 -0.001439  0.000559
# 69799  1557.754500  70904       NaN       NaN  0       NaN       NaN
# 69800  1557.774935  70905 -0.000120  0.000559  0 -0.000139  0.000559
# 69801  1557.795369  70906  0.000261  0.000559  0  0.000242  0.000559
# 69802  1557.815804  70907 -0.001008  0.000559  0 -0.001027  0.000559
# 69803  1557.836238  70908  0.000048  0.000559  0  0.000029  0.000559
# 69804  1557.856673  70909 -0.000074  0.000559  0 -0.000093  0.000559
# 69805  1557.877107  70910 -0.001153  0.000559  0 -0.001172  0.000559
# 69806  1557.897541  70911 -0.001025  0.000559  0 -0.001044  0.000559
# 69807  1557.917976  70912  0.000112  0.000559  0  0.000093  0.000559
# 69808  1557.938410  70913  0.000122  0.000559  0  0.000103  0.000559
# 69809  1557.958845  70914  0.000536  0.000559  0  0.000517  0.000559
#
# [69810 rows x 7 columns]

# %%
t=tbl.values[:,0]
fl=tbl.values[:,2]
print t
# Out:
# [  131.5127147   131.5331494   131.553584  ...,  1557.9179758  1557.9384103
#   1557.9588447]

# %%
t
# Out:
# array([  131.5127147,   131.5331494,   131.553584 , ...,  1557.9179758,
#         1557.9384103,  1557.9588447])

# %%
t=t[isnan(fl)==False]
fl=fl[isnan(fl)==False]
t=t[fl>-0.008]
fl=fl[fl>-0.008]

# %%
plt.plot(t,fl)#A

# %%
dis=[]
for i in range (1,len(t)):
    dis.append((t[i]-t[i-1]))
    
c=0
dis1=[]
dis1.append(dis[0])
for i in range (1,len(dis)):
    for j in range(len(dis1)):
        
        if (dis[i]==dis1[j]):
            c=1
            
    if(c==0):
        dis1.append(dis[i])
    c=0

# %%
dt=min(dis1)
n=len(t)

# %%
fft_x = fft(fl) / n # FFT Normalized
freq = fftfreq(n, dt)
plt.plot(freq,abs(fft_x))#B

# %%
plt.plot(freq,abs(fft_x)**2)#Potencias

# %%
c=abs(fft_x).argsort()[-1:][::-1]
#encuentro el valor maximo de fft_x

# %%
period=1/abs(freq[c][0])#como estoy en el espectro de frecuencias el tiempo
#es 1/fft_x. Esta expresado en dias
print "el periodo mas representativo es "
print period  #c
# Out:
# el periodo mas representativo es
# 9.13956498213

# %%
def prog(N):#D
    ind=(abs(fft_x)**2).argsort()[-N:][::-1]
    graf=zeros(len(fft_x))
    for i in range(len(ind)):
        graf[ind[i]]=(abs(fft_x)**2)[ind[i]]
    return graf

# %%
(abs(fft_x)**2)[(abs(fft_x)**2).argsort()[-10:][::-1]]
# Out:
# array([  4.38892855e-08,   4.38892855e-08,   3.27009088e-08,
#          3.27009088e-08,   2.50295125e-08,   2.50295125e-08,
#          2.12728984e-08,   2.12728984e-08,   1.97143247e-08,
#          1.97143247e-08])

# %%
#D
plt.plot(freq,prog(1),label=1)
plt.plot(freq,prog(2),label=2)
plt.plot(freq,prog(3),label=3)
plt.plot(freq,prog(4),label=4)
plt.plot(freq,prog(5),label=5)
plt.plot(freq,prog(6),label=6)
plt.plot(freq,prog(7),label=7)
plt.plot(freq,prog(8),label=8)
plt.plot(freq,prog(9),label=9)
plt.plot(freq,prog(10),label=10)
plt.legend()

# %%
#D
plt.plot(t,ifft(prog(10)),label=10)
plt.plot(t,ifft(prog(9)),label=9)
plt.plot(t,ifft(prog(8)),label=8)
plt.plot(t,ifft(prog(7)),label=7)
plt.plot(t,ifft(prog(6)),label=6)
plt.plot(t,ifft(prog(5)),label=5)
plt.plot(t,ifft(prog(4)),label=4)
plt.plot(t,ifft(prog(3)),label=3)
plt.plot(t,ifft(prog(2)),label=2)
plt.plot(t,ifft(prog(1)),label=1)



plt.xlim(0,2100)
plt.legend(loc=0)
# Out:
# /home/juanc/.local/lib/python2.7/site-packages/numpy/core/numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
lstsq()
